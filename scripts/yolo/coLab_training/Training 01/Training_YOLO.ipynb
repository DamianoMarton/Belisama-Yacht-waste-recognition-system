# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks() # Verifica che la GPU sia attiva
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# shell command copy dataset file
# !cp /content/drive/MyDrive/dataset.zip /content/

# %%
# !unzip -q /content/dataset.zip -d /content/dataset

# %%
# check
# !ls /content/dataset
# Out:
# data.yaml  images  labels

# %%
# !cat /content/dataset/data.yaml
# Out:
# path: /content/dataset
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: algae
#   1: aluminum_container
#   2: aluminum_foil
#   3: carton
#   4: disposable_cup
#   5: drink_can
#   6: drink_carton
#   7: other
#   8: plastic_bag
#   9: plastic_bottle
#   10: plastic_lid
#   11: plastic_straw
#   12: snack_packet
#   13: stick
#   14: styrofoam_piece

# %%
yolo_model = YOLO('yolo11n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 283.0MB/s 0.0s

# %%
results = yolo_model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    project='waste_recognition_CyberCat',
    name='experiment_2'
)
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=waste_recognition_CyberCat, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/waste_recognition_CyberCat/experiment_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    433597  ultralytics.nn.modules.head.Detect           [15, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,592,765 parameters, 2,592,749 gradients, 6.5 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3322.2±825.5 MB/s, size: 185.7 KB)
# train: Scanning /content/dataset/labels/train.cache... 4000 images, 282 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 1.5Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1358.6±838.9 MB/s, size: 189.1 KB)
# val: Scanning /content/dataset/labels/val.cache... 1000 images, 114 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 67.7Mit/s 0.0s
# Plotting labels to /content/waste_recognition_CyberCat/experiment_2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.000526, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 12 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/waste_recognition_CyberCat/experiment_2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.64G     0.9278      4.073      1.135        224        640: 100% ━━━━━━━━━━━━ 125/125 1.3it/s 1:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.0it/s 15.9s
#                    all       1000       2505    0.00727      0.684      0.084      0.068
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.41G     0.8697      3.047      1.118        193        640: 100% ━━━━━━━━━━━━ 125/125 1.4it/s 1:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 8.1s
#                    all       1000       2505      0.441      0.443      0.433      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.42G     0.8153      1.977       1.08        218        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.4s
#                    all       1000       2505      0.702      0.701      0.742      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.42G      0.754      1.357      1.037        190        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.2s
#                    all       1000       2505      0.861      0.809      0.878      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.44G     0.7034      1.095      1.006        212        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.4s
#                    all       1000       2505      0.929      0.829      0.916      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.45G     0.6766     0.9781     0.9896        217        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.931       0.86      0.935      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.45G     0.6617     0.9077     0.9857        191        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.4s
#                    all       1000       2505      0.941      0.864       0.94      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.45G     0.6394     0.8671     0.9743        210        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.936      0.905      0.954      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.45G     0.6381     0.8276     0.9702        185        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.3s
#                    all       1000       2505      0.948      0.896      0.954      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.45G     0.6221      0.795     0.9642        217        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.5s
#                    all       1000       2505      0.959      0.893      0.956      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.45G     0.6182     0.7754     0.9648        233        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6it/s 9.8s
#                    all       1000       2505      0.943      0.896      0.955      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.45G     0.6072     0.7516     0.9601        259        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505      0.952      0.891      0.956      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.45G     0.6016      0.727     0.9532        226        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.3s
#                    all       1000       2505      0.951      0.896      0.956      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.45G     0.6011     0.7172     0.9561        194        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.2s
#                    all       1000       2505      0.951       0.92      0.964      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.45G     0.5913     0.7011     0.9543        235        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 7.8s
#                    all       1000       2505      0.942      0.913      0.962      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.46G     0.5928     0.6931     0.9519        172        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.952      0.905      0.963      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.48G     0.5831     0.6659     0.9472        203        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.2s
#                    all       1000       2505      0.949      0.911      0.963      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.48G     0.5838     0.6606      0.946        228        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505      0.948      0.921      0.966       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.48G     0.5653     0.6384     0.9389        212        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.5s
#                    all       1000       2505      0.966      0.911      0.966      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.48G     0.5743     0.6407     0.9435        229        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.941      0.925      0.965       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.48G     0.5705     0.6277     0.9384        184        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 7.9s
#                    all       1000       2505      0.951      0.927      0.966      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.48G     0.5656     0.6169     0.9384        183        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.0s
#                    all       1000       2505      0.957       0.92      0.967      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.48G     0.5667      0.616     0.9413        190        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.966      0.923      0.971      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.48G     0.5544     0.5997     0.9343        186        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505      0.948      0.927      0.968      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.48G     0.5627     0.6034     0.9408        184        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.957      0.934      0.971      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.48G      0.558     0.5893     0.9354        174        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.0s
#                    all       1000       2505      0.955      0.931      0.969      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.48G     0.5544     0.5836     0.9367        203        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.4s
#                    all       1000       2505      0.956      0.935      0.972      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.48G     0.5516     0.5809     0.9369        183        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.2s
#                    all       1000       2505      0.961      0.925       0.97       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.48G     0.5509     0.5799     0.9359        205        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.7s
#                    all       1000       2505      0.963      0.927      0.971      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.48G     0.5442     0.5694     0.9314        217        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505       0.96      0.933      0.971      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.48G     0.5419     0.5591     0.9286        211        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.5s
#                    all       1000       2505      0.958      0.934      0.973      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.48G     0.5393     0.5528     0.9322        196        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.961      0.934      0.973      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.48G     0.5378     0.5525     0.9298        184        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.5s
#                    all       1000       2505      0.955      0.937      0.972      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.48G     0.5364     0.5425     0.9287        214        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.948      0.934       0.97      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.48G      0.533     0.5405      0.924        167        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.3s
#                    all       1000       2505       0.96      0.932      0.971      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.48G     0.5315     0.5336     0.9262        205        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505      0.959       0.93      0.971      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.48G     0.5318     0.5304     0.9255        180        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s
#                    all       1000       2505      0.961      0.935      0.971      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.48G     0.5322     0.5334     0.9251        220        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.1s
#                    all       1000       2505      0.964      0.928      0.973      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.48G     0.5244     0.5295     0.9254        157        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 7.9s
#                    all       1000       2505      0.963      0.931      0.972      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.48G     0.5273     0.5271     0.9251        179        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.6s
#                    all       1000       2505      0.963      0.932      0.972      0.856
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.48G     0.4182     0.4686     0.8589        150        640: 100% ━━━━━━━━━━━━ 125/125 1.5it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7it/s 9.2s
#                    all       1000       2505      0.963      0.927      0.971      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.48G     0.4063     0.4481     0.8515        127        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 8.9s
#                    all       1000       2505      0.964       0.92       0.97      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.48G     0.4043     0.4413     0.8553        110        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 8.9s
#                    all       1000       2505      0.959      0.931      0.971      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.48G     0.4051     0.4393     0.8553        108        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9it/s 8.5s
#                    all       1000       2505      0.966      0.923      0.969      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.48G     0.4004     0.4325     0.8535        129        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 8.1s
#                    all       1000       2505      0.955      0.938      0.971      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.48G     0.3974      0.432      0.852        106        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.5s
#                    all       1000       2505      0.957      0.936      0.971      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.48G     0.3974     0.4271     0.8504         99        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.8s
#                    all       1000       2505      0.955      0.941      0.972      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.48G     0.3957     0.4278     0.8526        117        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.2it/s 7.4s
#                    all       1000       2505      0.957      0.937      0.972      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.48G     0.3948     0.4258     0.8497        109        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.1it/s 7.5s
#                    all       1000       2505      0.957      0.935      0.972       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.48G     0.3909       0.42     0.8486        120        640: 100% ━━━━━━━━━━━━ 125/125 1.6it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 7.8s
#                    all       1000       2505      0.956      0.939      0.972       0.86
#
# 50 epochs completed in 1.255 hours.
# Optimizer stripped from /content/waste_recognition_CyberCat/experiment_2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/waste_recognition_CyberCat/experiment_2/weights/best.pt, 5.5MB
#
# Validating /content/waste_recognition_CyberCat/experiment_2/weights/best.pt...
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,585,077 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.2it/s 13.2s
#                    all       1000       2505      0.956      0.938      0.971      0.861
#                  algae        153        170      0.933      0.905      0.952      0.778
#     aluminum_container        165        183      0.971      0.995      0.995      0.921
#          aluminum_foil        153        168      0.982      0.974       0.98      0.902
#                 carton        145        158      0.969      0.994      0.994      0.937
#         disposable_cup        148        158      0.934      0.892       0.96      0.814
#              drink_can        154        178       0.97       0.91      0.969       0.83
#           drink_carton        148        162      0.954      0.963      0.987      0.873
#                  other        145        155       0.96      0.858       0.95      0.802
#            plastic_bag        147        160      0.989      0.963      0.986      0.943
#         plastic_bottle        171        193      0.978      0.931      0.975      0.872
#            plastic_lid        149        161      0.948      0.963      0.981       0.86
#          plastic_straw        154        163      0.927      0.933       0.97      0.852
#           snack_packet        167        181      0.973      0.961      0.993      0.878
#                  stick        150        158      0.875      0.841      0.887      0.708
#        styrofoam_piece        146        157      0.978      0.981      0.993      0.949
# Speed: 0.2ms preprocess, 2.5ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /content/waste_recognition_CyberCat/experiment_2

# %%
# !zip -r training_results_02.zip /content/waste_recognition_CyberCat/experiment_2
# Out:
#   adding: content/waste_recognition_CyberCat/experiment_2/ (stored 0%)
#   adding: content/waste_recognition_CyberCat/experiment_2/BoxPR_curve.png (deflated 12%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/labels.jpg (deflated 28%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch1_labels.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/confusion_matrix.png (deflated 17%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch0.jpg (deflated 1%)
#   adding: content/waste_recognition_CyberCat/experiment_2/weights/ (stored 0%)
#   adding: content/waste_recognition_CyberCat/experiment_2/weights/best.pt (deflated 10%)
#   adding: content/waste_recognition_CyberCat/experiment_2/weights/last.pt (deflated 10%)
#   adding: content/waste_recognition_CyberCat/experiment_2/results.png (deflated 9%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch0_labels.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch1.jpg (deflated 1%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch5002.jpg (deflated 6%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch2.jpg (deflated 1%)
#   adding: content/waste_recognition_CyberCat/experiment_2/args.yaml (deflated 52%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch5001.jpg (deflated 4%)
#   adding: content/waste_recognition_CyberCat/experiment_2/train_batch5000.jpg (deflated 3%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch2_pred.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/results.csv (deflated 71%)
#   adding: content/waste_recognition_CyberCat/experiment_2/BoxR_curve.png (deflated 7%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch1_pred.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/val_batch2_labels.jpg (deflated 5%)
#   adding: content/waste_recognition_CyberCat/experiment_2/confusion_matrix_normalized.png (deflated 14%)
#   adding: content/waste_recognition_CyberCat/experiment_2/BoxF1_curve.png (deflated 6%)
#   adding: content/waste_recognition_CyberCat/experiment_2/BoxP_curve.png (deflated 9%)

# %%
from google.colab import files
files.download('training_results_02.zip')

# %%
from google.colab import files
files.upload()

# %%
yolo_model = YOLO("best.pt")

# %%
results = yolo_model.val(data="/content/dataset/data.yaml", split="test")
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,585,077 parameters, 0 gradients, 6.3 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.5MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2875.5±933.1 MB/s, size: 186.0 KB)
# val: Scanning /content/dataset/labels/test... 800 images, 92 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 2.4Kit/s 0.3s
# val: New cache created: /content/dataset/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.9it/s 10.1s
#                    all        800       2052      0.969      0.939      0.977      0.861
#                  algae        116        127      0.932      0.862      0.933      0.755
#     aluminum_container        140        156      0.977      0.981      0.994       0.93
#          aluminum_foil        108        120          1      0.991      0.995      0.912
#                 carton        135        153      0.987      0.967      0.993      0.942
#         disposable_cup        128        137      0.975      0.845      0.971      0.802
#              drink_can        121        137      0.984      0.897      0.973      0.838
#           drink_carton        151        167      0.947      0.946      0.978      0.834
#                  other        119        134      0.984      0.948      0.989      0.866
#            plastic_bag        131        141      0.993      0.972      0.995      0.946
#         plastic_bottle        132        143      0.993      0.978      0.992      0.873
#            plastic_lid        114        125      0.963      0.968      0.989      0.847
#          plastic_straw        122        134      0.937      0.933      0.962      0.829
#           snack_packet        106        115      0.974      0.963      0.979      0.856
#                  stick        124        131      0.909      0.841      0.917      0.728
#        styrofoam_piece        120        132      0.978       0.99      0.995      0.954
# Speed: 1.4ms preprocess, 3.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/runs/detect/val
